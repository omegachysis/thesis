# %%
import stack_learning
from importlib import reload
reload(stack_learning)
stack_learning.experiment()
# Out:
# Running single layer learning trial...
# Stopping due to target loss reached
# Time:  14.007997751235962 seconds
# Target:
# mass at t0: tf.Tensor([255. 255. 255.], shape=(3,), dtype=float32)
# mass at tf: tf.Tensor([186.36844 104.84932 108.16169], shape=(3,), dtype=float32)
# Sample run:
#  step: 295, loss: 0.010, log10(loss): -2.001
# Running single layer learning trial...
# Stopping due to target loss reached
# Time:  51.74494934082031 seconds
# Target:
# mass at t0: tf.Tensor([255. 255. 255.], shape=(3,), dtype=float32)
# mass at tf: tf.Tensor([131.32321 130.29774 129.87851], shape=(3,), dtype=float32)
# Sample run:
#  step: 1587, loss: 0.010, log10(loss): -2.007
# Running single layer learning trial...
# Stopping due to target loss reached
# Time:  20.809932231903076 seconds
# Target:
# mass at t0: tf.Tensor([255. 255. 255.], shape=(3,), dtype=float32)
# mass at tf: tf.Tensor([208.95888 191.58891 167.62506], shape=(3,), dtype=float32)
# Sample run:
# ...

# %%
# Total time to train the three separate layers:
14.007997751235962 + 51.74494934082031 + 20.809932231903076
# Out:
# 86.56287932395935

# %%
# Total t ime to train the three images together:
51.86898422241211
# Out:
# 51.86898422241211
